# %% [markdown]
# # Dataset first commit

# %% [markdown]
# ## Dependencies: [Pandas](https://pandas.pydata.org/)

# %%
import pandas as pd

# %% [markdown]
# ### Dependencies: [Yfinance](https://pypi.org/project/yfinance/)
#
# ```bash
# poetry add yfinance
# ```

# %%
import yfinance as yf

# %%
ticker = "^BVSP"
start = "2025-10-01"
end="2025-11-01"
interval="1d"

df = yf.download(
    ticker,
    start=start,
    end=end,
    interval=interval,
    auto_adjust=True
)
df
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price          Close      High       Low      Open    Volume
# Ticker         ^BVSP     ^BVSP     ^BVSP     ^BVSP     ^BVSP
# Date
# 2025-10-01  145517.0  146879.0  145193.0  146237.0   8340700
# 2025-10-02  143950.0  145621.0  143635.0  145517.0   7245600
# 2025-10-03  144201.0  144518.0  143676.0  143950.0   6177600
# 2025-10-06  143608.0  144532.0  143376.0  144202.0   5981500
# 2025-10-07  141356.0  143606.0  141035.0  143606.0   9272700
# 2025-10-08  142145.0  142385.0  141356.0  141356.0   7525200
# 2025-10-09  141708.0  143212.0  141603.0  142148.0   6821400
# 2025-10-10  140680.0  142274.0  140231.0  141725.0   8280800
# 2025-10-13  141783.0  142303.0  140682.0  140682.0   5531200
# 2025-10-14  141683.0  142589.0  141334.0  141788.0   7122300
# 2025-10-15  142604.0  142905.0  141154.0  141683.0  10321000
# 2025-10-16  142200.0  143191.0  141446.0  142604.0   7391900
# 2025-10-17  143399.0  143425.0  141248.0  142200.0   8875100
# 2025-10-20  144509.0  145216.0  143396.0  143399.0   6793400
# 2025-10-21  144085.0  144795.0  143829.0  144509.0   6193200
# 2025-10-22  144873.0  145048.0  144039.0  144094.0   7025000
# 2025-10-23  145721.0  146358.0  144881.0  144881.0   6599600
# 2025-10-24  146172.0  147240.0  145721.0  145721.0   6491300
# 2025-10-27  146969.0  147977.0  146174.0  146174.0   6445200
# 2025-10-28  147429.0  147811.0  146575.0  146970.0   7108000
# 2025-10-29  148633.0  149067.0  147430.0  147430.0   7999500
# 2025-10-30  148780.0  149234.0  147547.0  148632.0   7300600
# 2025-10-31  149540.0  149636.0  148774.0  148774.0   8911000

# %%
isinstance(df.columns, pd.MultiIndex)
# Out:
# True

# %%
df.columns = df.columns.get_level_values(0)
df
# Out:
# Price          Close      High       Low      Open    Volume
# Date
# 2025-10-01  145517.0  146879.0  145193.0  146237.0   8340700
# 2025-10-02  143950.0  145621.0  143635.0  145517.0   7245600
# 2025-10-03  144201.0  144518.0  143676.0  143950.0   6177600
# 2025-10-06  143608.0  144532.0  143376.0  144202.0   5981500
# 2025-10-07  141356.0  143606.0  141035.0  143606.0   9272700
# 2025-10-08  142145.0  142385.0  141356.0  141356.0   7525200
# 2025-10-09  141708.0  143212.0  141603.0  142148.0   6821400
# 2025-10-10  140680.0  142274.0  140231.0  141725.0   8280800
# 2025-10-13  141783.0  142303.0  140682.0  140682.0   5531200
# 2025-10-14  141683.0  142589.0  141334.0  141788.0   7122300
# 2025-11-01 15:39:40.195 | INFO     | src.config:<module>:11 - PROJ_ROOT path is: C:\Repositories\omni-ml

# %%
class YfinancePandasDataset(Dataset):
    def __init__(self, ticker, start_date: str, end_date: str,interval="1d"):
        self.ticker = ticker
        self.start_date = start_date
        self.end_date = end_date
        self.interval = interval

    def load(self) -> Batch:        
        df = pd.DataFrame()
        try:
            df = yf.download(self.ticker, start=self.start_date, end=self.end_date,interval=self.interval,auto_adjust=True) # return pd.DataFrame
            if not df.empty:
                df.columns = df.columns.get_level_values(0)
                df["Ticker"] = self.ticker
            else:
                logger.warning(f'No data returned for {self.ticker}')
        except Exception as e:
            logger.error(f'Error loading {self.ticker}: {e}')

        return Batch(
            X=df
            )

# %% [markdown]
# #### Simple Test
#
# ```bash
# poetry run pytest
# ```

# %%
DatasetTestYfinancePandas = YfinancePandasDataset(
    ticker="^BVSP",
    start_date="2025-10-01",
    end_date="2025-11-01",
    interval="1d"
)

batch = DatasetTestYfinancePandas.load()
assert not batch.X.empty, "DataFrame should not be empty"
assert "Ticker" in batch.X.columns, "'Ticker' column should be present in DataFrame"

batch.X
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price          Close      High       Low      Open    Volume Ticker
# Date
# 2025-10-01  145517.0  146879.0  145193.0  146237.0   8340700  ^BVSP
# 2025-10-02  143950.0  145621.0  143635.0  145517.0   7245600  ^BVSP
# 2025-10-03  144201.0  144518.0  143676.0  143950.0   6177600  ^BVSP
# 2025-10-06  143608.0  144532.0  143376.0  144202.0   5981500  ^BVSP
# 2025-10-07  141356.0  143606.0  141035.0  143606.0   9272700  ^BVSP
# 2025-10-08  142145.0  142385.0  141356.0  141356.0   7525200  ^BVSP
# 2025-10-09  141708.0  143212.0  141603.0  142148.0   6821400  ^BVSP
# 2025-10-10  140680.0  142274.0  140231.0  141725.0   8280800  ^BVSP
# 2025-10-13  141783.0  142303.0  140682.0  140682.0   5531200  ^BVSP
# 2025-10-14  141683.0  142589.0  141334.0  141788.0   7122300  ^BVSP
# 2025-10-15  142604.0  142905.0  141154.0  141683.0  10321000  ^BVSP
# 2025-10-16  142200.0  143191.0  141446.0  142604.0   7391900  ^BVSP
# 2025-10-17  143399.0  143425.0  141248.0  142200.0   8875100  ^BVSP
# 2025-10-20  144509.0  145216.0  143396.0  143399.0   6793400  ^BVSP
# 2025-10-21  144085.0  144795.0  143829.0  144509.0   6193200  ^BVSP
# 2025-10-22  144873.0  145048.0  144039.0  144094.0   7025000  ^BVSP
# 2025-10-23  145721.0  146358.0  144881.0  144881.0   6599600  ^BVSP
# 2025-10-24  146172.0  147240.0  145721.0  145721.0   6491300  ^BVSP
# 2025-10-27  146969.0  147977.0  146174.0  146174.0   6445200  ^BVSP
# 2025-10-28  147429.0  147811.0  146575.0  146970.0   7108000  ^BVSP
# 2025-10-29  148633.0  149067.0  147430.0  147430.0   7999500  ^BVSP
# 2025-10-30  148780.0  149234.0  147547.0  148632.0   7300600  ^BVSP
# 2025-10-31  149540.0  149636.0  148774.0  148774.0   8911000  ^BVSP
