# %% [markdown]
# # Dataset use_case

# %%
from src.dataset.infrastructure.indicator import BcbIndicator
from datetime import datetime, timedelta

# %%
data = BcbIndicator().get_indicator(
    name="SELIC",
    start=datetime.today() - timedelta(days=5),
    end=datetime.today()
)

data
